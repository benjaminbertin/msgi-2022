# %% [markdown]
# # Examen du cours Introduction au Data Mining 2021-2022
#
# Le problème à résoudre est de prédire le producteur d'un vin donné en fonction d'un ensemble de caractéristiques.
# Nous connaissons la cible à prédire, c'est donc un problème d'apprentissage supervisé.
#
# Vous avez à votre disposition un dataset contenant les features pour chaque individus `data.data` et la cible `data.target`.
#
# Assurez vous de respecter les points importants de la méthodologie : exploration du dataset, création des jeux d'entrainement et de test, recherche des meilleurs hyperparamètres, validation croisée, comparaison de modèles, utilisation de la bonne métrique, validation finale sur le jeu de test.
#
# Note : tous les imports n'ont pas été fait, il manque notamment ceux nécessaire pour importer les algorithmes d'apprentissage et les métriques.

# %%
from sklearn.datasets import load_wine
data = load_wine()

# %%
data.keys()

# %%
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_predict
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
print(data.DESCR)
